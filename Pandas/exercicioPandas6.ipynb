# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Paper/Acessos_Banda_Larga_Fixa_2021.csv", sep=";")
df
# Out:
#           Ano  Mês  ...   Tipo de Pessoa Acessos
# 0        2021    7  ...  Pessoa Jurídica      10
# 1        2021    7  ...  Pessoa Jurídica       1
# 2        2021    7  ...  Pessoa Jurídica       2
# 3        2021    7  ...  Pessoa Jurídica       2
# 4        2021    7  ...  Pessoa Jurídica       3
# ...       ...  ...  ...              ...     ...
# 3210059  2021    1  ...  Pessoa Jurídica      10
# 3210060  2021    1  ...    Pessoa Física      19
# 3210061  2021    1  ...    Pessoa Física      23
# 3210062  2021    1  ...    Pessoa Física       1
# 3210063  2021    1  ...    Pessoa Física      17
#
# [3210064 rows x 14 columns]

# %%
#Verificando os dados
df.dtypes
# Out:
# Ano                       int64
# Mês                       int64
# Grupo Econômico          object
# Empresa                  object
# CNPJ                      int64
# Porte da Prestadora      object
# UF                       object
# Município                object
# Código IBGE Município     int64
# Faixa de Velocidade      object
# Tecnologia               object
# Meio de Acesso           object
# Tipo de Pessoa           object
# Acessos                   int64
# dtype: object

# %%
#Verificando se os dados são únicos
sorted(pd.unique(df['Código IBGE Município']))

# %%
#Contagem dos campos nulos
df.isna().sum()

# %% [markdown]
# Criar um filtro para filtrar portadoras diferentes ou de pequeno porte que sejam dos estados "PB", "CE", "RN"

# %%
df.loc[df.divulgacao_relatorio_numero == "***", ["divulgacao_relatorio_numero"]] = "NULL"

# %% [markdown]
# Tranformar os campos 'LTE', 'GSM', 'GPRS', 'OFDMA/TDD', 'EDGE'
# para 2G/3G/4G e 'FTTH''FTTB' para FIBRA
#
# 1.   Item da lista
# 2.   Item da lista

# %%
df.loc[df.divulgacao_relatorio_numero == "***", ["divulgacao_relatorio_numero"]] = "NULL"

# %%
df.loc[df.Tecnologia == "FTTB"]
# Out:
#           Ano  Mês Grupo Econômico  ... Meio de Acesso   Tipo de Pessoa Acessos
# 11       2021    7              OI  ...          Fibra  Pessoa Jurídica       2
# 22       2021    7              OI  ...          Fibra  Pessoa Jurídica       2
# 29       2021    7              OI  ...          Fibra  Pessoa Jurídica       4
# 30       2021    7              OI  ...          Fibra  Pessoa Jurídica       4
# 33       2021    7              OI  ...          Fibra  Pessoa Jurídica       5
# ...       ...  ...             ...  ...            ...              ...     ...
# 3202152  2021    1              OI  ...          Fibra  Pessoa Jurídica       1
# 3202154  2021    1              OI  ...          Fibra  Pessoa Jurídica       1
# 3202155  2021    1              OI  ...          Fibra  Pessoa Jurídica       1
# 3202157  2021    1              OI  ...          Fibra  Pessoa Jurídica       2
# 3202158  2021    1              OI  ...          Fibra  Pessoa Jurídica       1
#
# ...
