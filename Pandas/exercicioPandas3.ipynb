# %% [markdown]
# Escolher alguma coluna como padrão para o dataframe , o dataframe deve ter dropada qualquer coluna que não faça sentido a pesquisa , exemplo "numero da publicação" , tambem realizar a conversão para lingua portuguesa dos titulos das colunas

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/cadastro.csv")

# %%
df.head(1)
# Out:
#    ID num_publicacao  ... concessao_app_tipo_familias patente_concedida
# 0   1   AU2007202956  ...                       Grant               Yes
#
# [1 rows x 19 columns]

# %%
df.rename(columns={"row no": "ID", 
                   "publication number": "num_publicacao", 
                   "kind code": "tipo_cod", 
                   "title": "titulo", 
                   "priority document": "prioridade_doc", 
                   "priority country": "prioridade_pais", 
                   "earliest priority date": "primeira_data_prioritaria", 
                   "earliest priority year": "primeiro_ano_prioritario",
                   "application date	publication": "data_app_publicacao", 
                   "publication date": "data_publicacao", 
                   "publication year": "ano_publicacao", 
                   "applicant": "aplicacao", 
                   "inventors": "inventores", 
                   "ipc classes": "classes_ipc", 
                   "family members": "membros_familia", 
                   "family size": "tamanho_familia",
                   "wo in family": "quem_na_familia", 
                   "grant or application type families": "concessao_app_tipo_familias", 
                   "granted patent": "patente_concedida"},
          inplace=True)
