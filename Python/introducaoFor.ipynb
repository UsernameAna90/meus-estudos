# %%
#Escreva um algoritmo que gere e imprima os números ímpares entre 100 e 200:

i = 0
cem = 100
duz = 200

for i in range(cem, duz, 1):
  if i % 2 != 0:
    print(i)

# %%
#Faça um algoritmo que imprima na tela uma sequencia de N numeros pares:

i = 0
n = int(input("Digite um numero: "))

for i in range(0, n + 1, 1):
  if i % 2 == 0:
    print(i)

# %%
#Faça um algoritmo que leia um numero positivo e imprima seus divisores:

i = 0
n = int(input("Digite um número positivo: "))

while n <= 0:
  n = int(input(f"O numero {n} e negativo! Por favor, digite um numero positivo: "))

print(f"Os divisores de {n} são:")

for i in range(1, n, 1):
  if n % i == 0:
    print(i)
